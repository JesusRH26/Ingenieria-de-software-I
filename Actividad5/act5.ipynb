# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from funpymodeling.exploratory import freq_tbl

# %%
doc = pd.read_excel('Den.xlsx')

# %%
doc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6891 entries, 0 to 6890
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    6891 non-null   int64
#  1   last_scraped                                  6891 non-null   object
#  2   source                                        6891 non-null   object
#  3   description                                   6891 non-null   object
#  4   neighborhood_overview                         6891 non-null   object
#  5   host_name                                     6891 non-null   object
#  6   host_since                                    6891 non-null   object
#  7   host_response_time                            6891 non-null   object
#  8   host_is_superhost                             6891 non-null   object
# ...

# %%
doc = doc.drop('Unnamed: 0', axis=1)

doc.head()
# Out:
#   last_scraped       source  \
# 0   2024-09-30  city scrape
# 1   2024-09-29  city scrape
# 2   2024-09-30  city scrape
# 3   2024-09-30  city scrape
# 4   2024-09-30  city scrape
#
#                                          description  \
# 0  Amazing  modern, clean & fully equiped flat of...
# 1  Beach front apartment close to San Juan de Gaz...
# 2  The apartment is located in the mezzanine of a...
# 3                           No description available
# 4                           No description available
#
#                                neighborhood_overview host_name  host_since  \
# 0  Gros is Donosti's trendy neighborhood. The apa...     Mikel  2011-05-31
# 1                              No overview available   Maitane  2011-06-12
# 2  In this neighborhood with a strong personality...       Emy  2012-01-10
# 3  The apartment is located in the Romantic Area ...       Emy  2012-01-10
# 4  The apartment is located in the area known as ...       Emy  2012-01-10
#
# ...

# %%
doc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6891 entries, 0 to 6890
# Data columns (total 50 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   last_scraped                                  6891 non-null   object
#  1   source                                        6891 non-null   object
#  2   description                                   6891 non-null   object
#  3   neighborhood_overview                         6891 non-null   object
#  4   host_name                                     6891 non-null   object
#  5   host_since                                    6891 non-null   object
#  6   host_response_time                            6891 non-null   object
#  7   host_is_superhost                             6891 non-null   object
#  8   host_neighbourhood                            6891 non-null   object
# ...

# %%
freq_tbl(doc)
# Out:
#   last_scraped  frequency  percentage  cumulative_perc
# 0   2024-09-30       3839    0.557103         0.557103
# 1   2024-09-29       3052    0.442897         1.000000
#
# ----------------------------------------------------------------
#
#             source  frequency  percentage  cumulative_perc
# 0      city scrape       6258    0.908141         0.908141
# 1  previous scrape        633    0.091859         1.000000
#
# ----------------------------------------------------------------
#
#                                             description  frequency  \
# 0                              No description available        330
# 1     Enjoy the simplicity of this quiet, central home.         20
# 2     You share an apartment with other young people...         17
# 3     This home has peace of mind, relax with your w...         17
# 4     This home breathes peace of mind: Relax with t...         15
# ...                                                 ...        ...
# ...

# %%
doc['host_acceptance_rate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6891 entries, 0 to 6890
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 6891 non-null   float64
# dtypes: float64(1)
# memory usage: 54.0 KB

# %%
n = 6891

# %%
Max=doc['host_acceptance_rate'].max()
Min=doc['host_acceptance_rate'].min()
Limites =[Min, Max]
Limites
# Out:
# [0.75, 1.0]

# %%
R=Max- Min 
R
# Out:
# 0.25

# %%
ni = 1+3.322*np.log10(n)
ni
# Out:
# 13.750773634216594

# %%
i = R/ni
i
# Out:
# 0.018180795251978778

# %%
intervalos=np.linspace(Min, Max, 14)
intervalos
# Out:
# array([0.75      , 0.76923077, 0.78846154, 0.80769231, 0.82692308,
#        0.84615385, 0.86538462, 0.88461538, 0.90384615, 0.92307692,
#        0.94230769, 0.96153846, 0.98076923, 1.        ])

# %%
categorias= ["0.75 - 0.769", "0.769 - 0.788","0.788 - 0.807","0.807 - 0.826","0.826 - 0.846","0.846 - 0.865","0.865 - 0.884","0.884 - 0.903","0.903 - 0.923","0.923 - 0.942","0.942 - 0.961","0.961 - 0.980","0.980 - 1"]

# %%
doc['host_acceptance_rate']=pd.cut(x= doc["host_acceptance_rate"], bins=intervalos, labels = categorias)
doc['host_acceptance_rate']
# Out:
# 0           0.980 - 1
# 1           0.980 - 1
# 2       0.884 - 0.903
# 3       0.884 - 0.903
# 4       0.884 - 0.903
#             ...
# 6886        0.980 - 1
# 6887        0.980 - 1
# 6888        0.980 - 1
# 6889        0.980 - 1
# 6890    0.884 - 0.903
# Name: host_acceptance_rate, Length: 6891, dtype: category
# Categories (13, object): ['0.75 - 0.769' < '0.769 - 0.788' < '0.788 - 0.807' < '0.807 - 0.826' ... '0.923 - 0.942' < '0.942 - 0.961' < '0.961 - 0.980' < '0.980 - 1']

# %%
table1 = freq_tbl(doc['host_acceptance_rate'])
table1
# Out:
#    host_acceptance_rate  frequency  percentage  cumulative_perc
# 0             0.980 - 1       4889    0.709476         0.714975
# 1         0.961 - 0.980        481    0.069801         0.785317
# 2         0.884 - 0.903        458    0.066464         0.852296
# 3         0.942 - 0.961        231    0.033522         0.886078
# 4         0.923 - 0.942        204    0.029604         0.915911
# 5         0.903 - 0.923        131    0.019010         0.935069
# 6         0.826 - 0.846         91    0.013206         0.948377
# 7         0.865 - 0.884         89    0.012915         0.961392
# 8         0.846 - 0.865         88    0.012770         0.974261
# 9         0.788 - 0.807         74    0.010739         0.985083
# 10        0.769 - 0.788         45    0.006530         0.991664
# 11        0.807 - 0.826         35    0.005079         0.996783
# 12         0.75 - 0.769         22    0.003193         1.000000

# %%
table1_1 = table1.drop(['percentage','cumulative_perc'], axis=1)
table1_1
# Out:
#    host_acceptance_rate  frequency
# 0             0.980 - 1       4889
# 1         0.961 - 0.980        481
# 2         0.884 - 0.903        458
# 3         0.942 - 0.961        231
# 4         0.923 - 0.942        204
# 5         0.903 - 0.923        131
# 6         0.826 - 0.846         91
# 7         0.865 - 0.884         89
# 8         0.846 - 0.865         88
# 9         0.788 - 0.807         74
# 10        0.769 - 0.788         45
# 11        0.807 - 0.826         35
# 12         0.75 - 0.769         22

# %%
fil1 = table1_1[table1_1['frequency']>1]
fil1
# Out:
#    host_acceptance_rate  frequency
# 0             0.980 - 1       4889
# 1         0.961 - 0.980        481
# 2         0.884 - 0.903        458
# 3         0.942 - 0.961        231
# 4         0.923 - 0.942        204
# 5         0.903 - 0.923        131
# 6         0.826 - 0.846         91
# 7         0.865 - 0.884         89
# 8         0.846 - 0.865         88
# 9         0.788 - 0.807         74
# 10        0.769 - 0.788         45
# 11        0.807 - 0.826         35
# 12         0.75 - 0.769         22

# %%
filI1 = fil1.set_index('host_acceptance_rate')
filI1
# Out:
#                       frequency
# host_acceptance_rate
# 0.980 - 1                  4889
# 0.961 - 0.980               481
# 0.884 - 0.903               458
# 0.942 - 0.961               231
# 0.923 - 0.942               204
# 0.903 - 0.923               131
# 0.826 - 0.846                91
# 0.865 - 0.884                89
# 0.846 - 0.865                88
# 0.788 - 0.807                74
# 0.769 - 0.788                45
# 0.807 - 0.826                35
# 0.75 - 0.769                 22

# %%
filI1.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Cantidad de aceptacion')
plt.xlabel('Cantidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
table1.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
filI1.plot(kind='area', figsize=(10,4), alpha = 0.8)
# Out:
# <Axes: xlabel='host_acceptance_rate'>

# %%
filI1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct= "%0.1f ")
# Out:
# <Axes: ylabel='frequency'>

# %%
doc['accommodates'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6891 entries, 0 to 6890
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 6891 non-null   float64
# dtypes: float64(1)
# memory usage: 54.0 KB

# %%
n = 6891

# %%
Max=doc['accommodates'].max()
Min=doc['accommodates'].min()
Limites =[Min, Max]
Limites
# Out:
# [1.0, 9.0]

# %%
R=Max- Min 
R
# Out:
# 8.0

# %%
ni = 1+3.322*np.log10(n)
ni
# Out:
# 13.750773634216594

# %%
i = R/ni
i
# Out:
# 0.5817854480633209

# %%
intervalos=np.linspace(Min, Max, 10)
intervalos
# Out:
# array([1.        , 1.88888889, 2.77777778, 3.66666667, 4.55555556,
#        5.44444444, 6.33333333, 7.22222222, 8.11111111, 9.        ])

# %%
categorias= ["1", "2", "3", "4", "5", "6", "7", "8", " 9"]

# %%
doc['accommodates']=pd.cut(x= doc["accommodates"], bins=intervalos, labels = categorias)
doc['accommodates']
# Out:
# 0         4
# 1         4
# 2         6
# 3         8
# 4         8
#        ...
# 6886      4
# 6887    NaN
# 6888      6
# 6889      4
# 6890      2
# Name: accommodates, Length: 6891, dtype: category
# Categories (9, object): ['1' < '2' < '3' < '4' ... '6' < '7' < '8' < ' 9']

# %%
filI2 = freq_tbl(doc['accommodates'])
filI2
# Out:
#   accommodates  frequency  percentage  cumulative_perc
# 0            4       2226    0.323030         0.340003
# 1            2       1800    0.261210         0.614938
# 2            3        779    0.113046         0.733924
# 3            6        719    0.104339         0.843745
# 4            5        573    0.083152         0.931266
# 5            8        310    0.044986         0.978616
# 6            7        119    0.017269         0.996792
# 7            9         21    0.003047         1.000000
# 8            1          0    0.000000         1.000000

# %%
filI2_1 = filI2.drop(['percentage','cumulative_perc'], axis=1)
filI2_1
# Out:
#   accommodates  frequency
# 0            4       2226
# 1            2       1800
# 2            3        779
# 3            6        719
# 4            5        573
# 5            8        310
# 6            7        119
# 7            9         21
# 8            1          0

# %%
filI2 = filI2_1[filI2_1['frequency']>1]
filI2
# Out:
#   accommodates  frequency
# 0            4       2226
# 1            2       1800
# 2            3        779
# 3            6        719
# 4            5        573
# 5            8        310
# 6            7        119
# 7            9         21

# %%
filI1 = filI2.set_index('accommodates')
filI1
# Out:
#               frequency
# accommodates
# 3                  2226
# 1                  1800
# 2                   779
# 5                   719
# 4                   573
# 7                   310
# 6                   119
# 8                    21

# %%
filI1.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Residentes')
plt.xlabel('Cantidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
filI2.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
filI1.plot(kind='area', figsize=(10,4), alpha = 0.8)
# Out:
# <Axes: xlabel='accommodates'>

# %%
filI1["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct= "%0.1f ")
# Out:
# <Axes: ylabel='frequency'>

# %%
doc['beds'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6891 entries, 0 to 6890
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 6891 non-null   float64
# dtypes: float64(1)
# memory usage: 54.0 KB

# %%
n = 6891

# %%
Max=doc['beds'].max()
Min=doc['beds'].min()
Limites =[Min, Max]
Limites
# Out:
# [0.0, 8.0]

# %%
R=Max- Min 
R
# Out:
# 8.0

# %%
ni = 1+3.322*np.log10(n)
ni
# Out:
# 13.750773634216594

# %%
i = R/ni
i
# Out:
# 0.5817854480633209

# %%
intervalos=np.linspace(Min, Max, 13)
intervalos
# Out:
# array([0.        , 0.66666667, 1.33333333, 2.        , 2.66666667,
#        3.33333333, 4.        , 4.66666667, 5.33333333, 6.        ,
#        6.66666667, 7.33333333, 8.        ])

# %%
categorias = ["0", "1","2","3","4","5","6","7","8"]

# %%
doc['beds']=pd.cut(x= doc["beds"], bins=intervalos, labels = categorias)
doc['beds']
# Out:
# 0       3
# 1       3
# 2       4
# 3       5
# 4       5
#        ..
# 6886    2
# 6887    1
# 6888    3
# 6889    3
# 6890    1
# Name: beds, Length: 6891, dtype: category
# Categories (9, object): ['0' < '1' < '2' < '3' ... '5' < '6' < '7' < '8']

# %%
table24 = freq_tbl(doc['beds'])
table24
# Out:
# 'No categorical variables to analyze.'

# %%
table24_1 = table24.drop(['percentage','cumulative_perc'], axis=1)
table24_1
# Out:
#   beds  frequency
# 0    3       2163
# 1    1       1649
# 2    2       1269
# 3    4        843
# 4    5        463
# 5    6        220
# 6    7        106
# 7    8         79
# 8    0          0

# %%
doc['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6891 entries, 0 to 6890
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 6891 non-null   float64
# dtypes: float64(1)
# memory usage: 54.0 KB

# %%
n
# Out:
# 6891

# %%
Max=doc['price'].max()
Min=doc['price'].min()
Limites =[Min, Max]
Limites
# Out:
# [13.0, 312.0]

# %%
R=Max- Min
R
# Out:
# 299.0

# %%
ni = 1+3.322*np.log10(n)
ni
# Out:
# 13.750773634216594

# %%
i = R/ni
i
# Out:
# 21.744231121366617

# %%
intervalos=np.linspace(Min, Max, 14)
intervalos
# Out:
# array([ 13.,  36.,  59.,  82., 105., 128., 151., 174., 197., 220., 243.,
#        266., 289., 312.])

# %%
categorias= ["13 - 36","36 - 59","59 - 82","82 - 105","105 - 128","128 - 151","151- 174","174 - 197","197 - 220","220 - 243","243 - 266","266 - 289","289 - 312"]

# %%
doc["price"]=pd.cut(x= doc["price"], bins=intervalos, labels = categorias)
doc["price"]
# Out:
# 0       174 - 197
# 1        151- 174
# 2       197 - 220
# 3       243 - 266
# 4       243 - 266
#           ...
# 6886    128 - 151
# 6887      36 - 59
# 6888    197 - 220
# 6889    197 - 220
# 6890     82 - 105
# Name: price, Length: 6891, dtype: category
# Categories (13, object): ['13 - 36' < '36 - 59' < '59 - 82' < '82 - 105' ... '220 - 243' < '243 - 266' < '266 - 289' < '289 - 312']

# %%
table25 = freq_tbl(doc['price'])
table25
# Out:
#         price  frequency  percentage  cumulative_perc
# 0   128 - 151       1272    0.184589         0.184615
# 1    151- 174       1053    0.152808         0.337446
# 2    82 - 105       1015    0.147294         0.484761
# 3   105 - 128        904    0.131186         0.615965
# 4     59 - 82        727    0.105500         0.721480
# 5     36 - 59        417    0.060514         0.782003
# 6   174 - 197        365    0.052968         0.834978
# 7   197 - 220        309    0.044841         0.879826
# 8     13 - 36        227    0.032942         0.912772
# 9   220 - 243        196    0.028443         0.941219
# 10  243 - 266        175    0.025395         0.966618
# 11  289 - 312        118    0.017124         0.983745
# 12  266 - 289        112    0.016253         1.000000

# %%
table25 = freq_tbl(doc['price'])
table25
# Out:
#         price  frequency  percentage  cumulative_perc
# 0   128 - 151       1272    0.184589         0.184615
# 1    151- 174       1053    0.152808         0.337446
# 2    82 - 105       1015    0.147294         0.484761
# 3   105 - 128        904    0.131186         0.615965
# 4     59 - 82        727    0.105500         0.721480
# 5     36 - 59        417    0.060514         0.782003
# 6   174 - 197        365    0.052968         0.834978
# 7   197 - 220        309    0.044841         0.879826
# 8     13 - 36        227    0.032942         0.912772
# 9   220 - 243        196    0.028443         0.941219
# 10  243 - 266        175    0.025395         0.966618
# 11  289 - 312        118    0.017124         0.983745
# 12  266 - 289        112    0.016253         1.000000

# %%
table25_1 = table25.drop(['percentage','cumulative_perc'], axis=1)
table25_1
# Out:
#         price  frequency
# 0   128 - 151       1272
# 1    151- 174       1053
# 2    82 - 105       1015
# 3   105 - 128        904
# 4     59 - 82        727
# 5     36 - 59        417
# 6   174 - 197        365
# 7   197 - 220        309
# 8     13 - 36        227
# 9   220 - 243        196
# 10  243 - 266        175
# 11  289 - 312        118
# 12  266 - 289        112

# %%
Filtro25 = table25_1[table25_1['frequency']>1]
Filtro25
# Out:
#         price  frequency
# 0   128 - 151       1272
# 1    151- 174       1053
# 2    82 - 105       1015
# 3   105 - 128        904
# 4     59 - 82        727
# 5     36 - 59        417
# 6   174 - 197        365
# 7   197 - 220        309
# 8     13 - 36        227
# 9   220 - 243        196
# 10  243 - 266        175
# 11  289 - 312        118
# 12  266 - 289        112

# %%
Filtro_index25 = Filtro25.set_index('price')
Filtro_index25
# Out:
#            frequency
# price
# 128 - 151       1272
# 151- 174        1053
# 82 - 105        1015
# 105 - 128        904
# 59 - 82          727
# 36 - 59          417
# 174 - 197        365
# 197 - 220        309
# 13 - 36          227
# 220 - 243        196
# 243 - 266        175
# 289 - 312        118
# 266 - 289        112

# %%
Filtro_index25.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Precios')
plt.xlabel('Cantidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
table25.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Filtro_index25.plot(kind='area', figsize=(10,4), alpha = 0.8)
# Out:
# <Axes: xlabel='price'>

# %%
Filtro_index25["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct= "%0.1f ")
# Out:
# <Axes: ylabel='frequency'>

# %%
doc['maximum_nights_avg_ntm'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6891 entries, 0 to 6890
# Series name: maximum_nights_avg_ntm
# Non-Null Count  Dtype
# --------------  -----
# 6891 non-null   float64
# dtypes: float64(1)
# memory usage: 54.0 KB

# %%
n
# Out:
# 6891

# %%
Max=doc['maximum_nights_avg_ntm'].max()
Min=doc['maximum_nights_avg_ntm'].min()
Limites =[Min, Max]
Limites
# Out:
# [2.0, 1500.0]

# %%
R=Max- Min
R
# Out:
# 1498.0

# %%
ni = 1+3.322*np.log10(n)
ni
# Out:
# 13.750773634216594

# %%
i = R/ni
i
# Out:
# 108.93932514985683

# %%
intervalos=np.linspace(Min, Max, 14)
intervalos
# Out:
# array([   2.        ,  117.23076923,  232.46153846,  347.69230769,
#         462.92307692,  578.15384615,  693.38461538,  808.61538462,
#         923.84615385, 1039.07692308, 1154.30769231, 1269.53846154,
#        1384.76923077, 1500.        ])

# %%
categorias =["2 - 117", "117 - 232","232 - 347","347 - 462","462 - 578","578 - 693","693 - 808","808 - 923","923 - 1039","1039 - 1154","1154 - 1269","1269 - 1384","1384 - 1500",]

# %%
doc['maximum_nights_avg_ntm']=pd.cut(x= doc["maximum_nights_avg_ntm"], bins=intervalos, labels = categorias)
doc['maximum_nights_avg_ntm']
# Out:
# 0           2 - 117
# 1       1039 - 1154
# 2         347 - 462
# 3         232 - 347
# 4         117 - 232
#            ...
# 6886      347 - 462
# 6887      347 - 462
# 6888      347 - 462
# 6889     923 - 1039
# 6890      347 - 462
# Name: maximum_nights_avg_ntm, Length: 6891, dtype: category
# Categories (13, object): ['2 - 117' < '117 - 232' < '232 - 347' < '347 - 462' ... '1039 - 1154' < '1154 - 1269' < '1269 - 1384' < '1384 - 1500']

# %%
table26 = freq_tbl(doc['maximum_nights_avg_ntm'])
table26
# Out:
#    maximum_nights_avg_ntm  frequency  percentage  cumulative_perc
# 0             1039 - 1154       2818    0.408939         0.409236
# 1               347 - 462       1812    0.262952         0.672379
# 2                 2 - 117       1302    0.188942         0.861458
# 3              923 - 1039        327    0.047453         0.908946
# 4               117 - 232        180    0.026121         0.935086
# 5               808 - 923        131    0.019010         0.954110
# 6               693 - 808        120    0.017414         0.971536
# 7               232 - 347        117    0.016979         0.988527
# 8               462 - 578         52    0.007546         0.996079
# 9               578 - 693         26    0.003773         0.999855
# 10            1384 - 1500          1    0.000145         1.000000
# 11            1154 - 1269          0    0.000000         1.000000
# 12            1269 - 1384          0    0.000000         1.000000

# %%
table26_1 = table26.drop(['percentage','cumulative_perc'], axis=1)
table26_1
# Out:
#    maximum_nights_avg_ntm  frequency
# 0             1039 - 1154       2818
# 1               347 - 462       1812
# 2                 2 - 117       1302
# 3              923 - 1039        327
# 4               117 - 232        180
# 5               808 - 923        131
# 6               693 - 808        120
# 7               232 - 347        117
# 8               462 - 578         52
# 9               578 - 693         26
# 10            1384 - 1500          1
# 11            1154 - 1269          0
# 12            1269 - 1384          0

# %%
Filtro26 = table26_1[table26_1['frequency']>1]
Filtro26
# Out:
#   maximum_nights_avg_ntm  frequency
# 0            1039 - 1154       2818
# 1              347 - 462       1812
# 2                2 - 117       1302
# 3             923 - 1039        327
# 4              117 - 232        180
# 5              808 - 923        131
# 6              693 - 808        120
# 7              232 - 347        117
# 8              462 - 578         52
# 9              578 - 693         26

# %%
Filtro_index26 = Filtro26.set_index('maximum_nights_avg_ntm')
Filtro_index26
# Out:
#                         frequency
# maximum_nights_avg_ntm
# 1039 - 1154                  2818
# 347 - 462                    1812
# 2 - 117                      1302
# 923 - 1039                    327
# 117 - 232                     180
# 808 - 923                     131
# 693 - 808                     120
# 232 - 347                     117
# 462 - 578                      52
# 578 - 693                      26

# %%
Filtro_index26.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Noches maximas medias')
plt.xlabel('Cantidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
table26.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Filtro_index26.plot(kind='area', figsize=(10,4), alpha = 0.8)
# Out:
# <Axes: xlabel='maximum_nights_avg_ntm'>

# %%
Filtro_index26["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct= "%0.1f ")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# **number_of_reviews**

# %%
doc['number_of_reviews'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6891 entries, 0 to 6890
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 6891 non-null   float64
# dtypes: float64(1)
# memory usage: 54.0 KB

# %%
n
# Out:
# 6891

# %%
 
Max=doc['number_of_reviews'].max()
Min=doc['number_of_reviews'].min()
Limites =[Min, Max]
Limites
# Out:
# [0.0, 134.0]

# %%
 
R=Max- Min
R
# Out:
# 134.0

# %%
 
ni = 1+3.322*np.log10(n)
ni
# Out:
# 13.750773634216594

# %%
 
i = R/ni
i
# Out:
# 9.744906255060624

# %%
 
intervalos=np.linspace(Min, Max, 14)
intervalos
# Out:
# array([  0.        ,  10.30769231,  20.61538462,  30.92307692,
#         41.23076923,  51.53846154,  61.84615385,  72.15384615,
#         82.46153846,  92.76923077, 103.07692308, 113.38461538,
#        123.69230769, 134.        ])

# %%
categorias= ["0 - 10","10 - 20","20 -30","30 - 41","41 - 51","51 - 61","61 - 72","72 - 82","82 - 92","92 - 103","103 - 113","113 - 123","123 - 134"]

# %%
 
doc['number_of_reviews']=pd.cut(x= doc["number_of_reviews"], bins=intervalos, labels = categorias)
doc['number_of_reviews']
# Out:
# 0        20 -30
# 1       72 - 82
# 2       10 - 20
# 3       10 - 20
# 4       10 - 20
#          ...
# 6886        NaN
# 6887        NaN
# 6888        NaN
# 6889        NaN
# 6890        NaN
# Name: number_of_reviews, Length: 6891, dtype: category
# Categories (13, object): ['0 - 10' < '10 - 20' < '20 -30' < '30 - 41' ... '92 - 103' < '103 - 113' < '113 - 123' < '123 - 134']

# %%
table27 = freq_tbl(doc['number_of_reviews'])
table27
# Out:
#    number_of_reviews  frequency  percentage  cumulative_perc
# 0             0 - 10       1999    0.290089         0.322784
# 1             20 -30       1259    0.182702         0.526078
# 2            10 - 20        903    0.131040         0.671888
# 3            30 - 41        490    0.071107         0.751009
# 4            41 - 51        370    0.053693         0.810754
# 5            51 - 61        276    0.040052         0.855321
# 6            61 - 72        221    0.032071         0.891006
# 7            72 - 82        179    0.025976         0.919910
# 8            82 - 92        133    0.019301         0.941385
# 9          103 - 113        107    0.015527         0.958663
# 10          92 - 103        104    0.015092         0.975456
# 11         123 - 134         78    0.011319         0.988051
# 12         113 - 123         74    0.010739         1.000000

# %%
table27_1 = table27.drop(['percentage','cumulative_perc'], axis=1)
table27_1
# Out:
#    number_of_reviews  frequency
# 0             0 - 10       1999
# 1             20 -30       1259
# 2            10 - 20        903
# 3            30 - 41        490
# 4            41 - 51        370
# 5            51 - 61        276
# 6            61 - 72        221
# 7            72 - 82        179
# 8            82 - 92        133
# 9          103 - 113        107
# 10          92 - 103        104
# 11         123 - 134         78
# 12         113 - 123         74

# %%
Filtro27 = table27_1[table27_1['frequency']>1]
Filtro27
# Out:
#    number_of_reviews  frequency
# 0             0 - 10       1999
# 1             20 -30       1259
# 2            10 - 20        903
# 3            30 - 41        490
# 4            41 - 51        370
# 5            51 - 61        276
# 6            61 - 72        221
# 7            72 - 82        179
# 8            82 - 92        133
# 9          103 - 113        107
# 10          92 - 103        104
# 11         123 - 134         78
# 12         113 - 123         74

# %%
 
Filtro_index27 = Filtro27.set_index('number_of_reviews')
Filtro_index27
# Out:
#                    frequency
# number_of_reviews
# 0 - 10                  1999
# 20 -30                  1259
# 10 - 20                  903
# 30 - 41                  490
# 41 - 51                  370
# 51 - 61                  276
# 61 - 72                  221
# 72 - 82                  179
# 82 - 92                  133
# 103 - 113                107
# 92 - 103                 104
# 123 - 134                 78
# 113 - 123                 74

# %%
Filtro_index27.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Numero de reseñas')
plt.xlabel('Cantidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
 
table27.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Filtro_index27.plot(kind='area', figsize=(10,4), alpha = 0.8)
# Out:
# <Axes: xlabel='number_of_reviews'>

# %%
Filtro_index27["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct= "%0.1f ")
# Out:
# <Axes: ylabel='frequency'>

# %%
 
doc['review_scores_location'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6891 entries, 0 to 6890
# Series name: review_scores_location
# Non-Null Count  Dtype
# --------------  -----
# 6891 non-null   float64
# dtypes: float64(1)
# memory usage: 54.0 KB

# %%
n
# Out:
# 6891

# %%
 
Max=doc['review_scores_location'].max()
Min=doc['review_scores_location'].min()
Limites =[Min, Max]
Limites
# Out:
# [4.25, 5.0]

# %%
 
R=Max- Min
R
# Out:
# 0.75

# %%
 
ni = 1+3.322*np.log10(n)
ni
# Out:
# 13.750773634216594

# %%
 
i = R/ni
i
# Out:
# 0.054542385755936326

# %%
 
intervalos=np.linspace(Min, Max, 6)
intervalos
# Out:
# array([4.25, 4.4 , 4.55, 4.7 , 4.85, 5.  ])

# %%
categorias = ["4.25 - 4.4", "4.4 - 4.55", "4.55 - 4.7" , "4.7 - 4.85" , "4.85 - 5"]

# %%
 
doc['review_scores_location']=pd.cut(x= doc["review_scores_location"], bins=intervalos, labels = categorias)
doc['review_scores_location']
# Out:
# 0         4.85 - 5
# 1       4.55 - 4.7
# 2         4.85 - 5
# 3         4.85 - 5
# 4       4.7 - 4.85
#            ...
# 6886    4.55 - 4.7
# 6887    4.55 - 4.7
# 6888    4.55 - 4.7
# 6889    4.55 - 4.7
# 6890    4.55 - 4.7
# Name: review_scores_location, Length: 6891, dtype: category
# Categories (5, object): ['4.25 - 4.4' < '4.4 - 4.55' < '4.55 - 4.7' < '4.7 - 4.85' < '4.85 - 5']

# %%
table28 = freq_tbl(doc['review_scores_location'])
table28
# Out:
#   review_scores_location  frequency  percentage  cumulative_perc
# 0               4.85 - 5       2935    0.425918         0.427593
# 1             4.7 - 4.85       1775    0.257582         0.686189
# 2             4.55 - 4.7       1474    0.213902         0.900932
# 3             4.4 - 4.55        442    0.064142         0.965326
# 4             4.25 - 4.4        238    0.034538         1.000000

# %%
table28 = freq_tbl(doc['review_scores_location'])
table28
# Out:
#   review_scores_location  frequency  percentage  cumulative_perc
# 0               4.85 - 5       2935    0.425918         0.427593
# 1             4.7 - 4.85       1775    0.257582         0.686189
# 2             4.55 - 4.7       1474    0.213902         0.900932
# 3             4.4 - 4.55        442    0.064142         0.965326
# 4             4.25 - 4.4        238    0.034538         1.000000

# %%
table28_1 = table28.drop(['percentage','cumulative_perc'], axis=1)
table28_1
# Out:
#   review_scores_location  frequency
# 0               4.85 - 5       2935
# 1             4.7 - 4.85       1775
# 2             4.55 - 4.7       1474
# 3             4.4 - 4.55        442
# 4             4.25 - 4.4        238

# %%
Filtro28 = table28_1[table28_1['frequency']>1]
Filtro28
# Out:
#   review_scores_location  frequency
# 0               4.85 - 5       2935
# 1             4.7 - 4.85       1775
# 2             4.55 - 4.7       1474
# 3             4.4 - 4.55        442
# 4             4.25 - 4.4        238

# %%
 
Filtro_index28 = Filtro28.set_index('review_scores_location')
Filtro_index28
# Out:
#                         frequency
# review_scores_location
# 4.85 - 5                     2935
# 4.7 - 4.85                   1775
# 4.55 - 4.7                   1474
# 4.4 - 4.55                    442
# 4.25 - 4.4                    238

# %%
Filtro_index28.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Puntuacion de la ubicacion')
plt.xlabel('Puntuacion')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
 
table28.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Filtro_index28.plot(kind='area', figsize=(10,4), alpha = 0.8)
# Out:
# <Axes: xlabel='review_scores_location'>

# %%
Filtro_index28["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct= "%0.1f ")
# Out:
# <Axes: ylabel='frequency'>

# %%
 
doc['review_scores_value'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6891 entries, 0 to 6890
# Series name: review_scores_value
# Non-Null Count  Dtype
# --------------  -----
# 6891 non-null   float64
# dtypes: float64(1)
# memory usage: 54.0 KB

# %%
n
# Out:
# 6891

# %%
 
Max=doc['review_scores_value'].max()
Min=doc['review_scores_value'].min()
Limites =[Min, Max]
Limites
# Out:
# [4.04, 5.0]

# %%
 
R=Max- Min
R
# Out:
# 0.96

# %%
 
ni = 1+3.322*np.log10(n)
ni
# Out:
# 13.750773634216594

# %%
 
i = R/ni
i
# Out:
# 0.06981425376759849

# %%
 
intervalos=np.linspace(Min, Max, 13)
intervalos
# Out:
# array([4.04, 4.12, 4.2 , 4.28, 4.36, 4.44, 4.52, 4.6 , 4.68, 4.76, 4.84,
#        4.92, 5.  ])

# %%
categorias = ["4.04 - 4.12","4.12 - 4.2","4.2 - 4.28","4.28 - 4.36","4.36 - 4.44","4.44 - 4.52","4.52 - 4.6", "4.6 - 4.68","4.68 - 4.76","4.76 - 4.84","4.84 - 4.92","4.92 - 5"]

# %%
 
doc['review_scores_value']=pd.cut(x= doc["review_scores_value"], bins=intervalos, labels = categorias)
doc['review_scores_value']
# Out:
# 0       4.68 - 4.76
# 1       4.68 - 4.76
# 2        4.12 - 4.2
# 3        4.52 - 4.6
# 4       4.68 - 4.76
#            ...
# 6886     4.52 - 4.6
# 6887     4.52 - 4.6
# 6888     4.52 - 4.6
# 6889     4.52 - 4.6
# 6890     4.52 - 4.6
# Name: review_scores_value, Length: 6891, dtype: category
# Categories (12, object): ['4.04 - 4.12' < '4.12 - 4.2' < '4.2 - 4.28' < '4.28 - 4.36' ... '4.68 - 4.76' < '4.76 - 4.84' < '4.84 - 4.92' < '4.92 - 5']

# %%
table29 = freq_tbl(doc['review_scores_value'])
table29
# Out:
#    review_scores_value  frequency  percentage  cumulative_perc
# 0          4.68 - 4.76       1327    0.192570         0.192682
# 1           4.52 - 4.6       1248    0.181106         0.373893
# 2          4.76 - 4.84        810    0.117545         0.491506
# 3             4.92 - 5        773    0.112175         0.603746
# 4           4.6 - 4.68        717    0.104049         0.707855
# 5          4.84 - 4.92        622    0.090263         0.798170
# 6          4.44 - 4.52        486    0.070527         0.868738
# 7          4.36 - 4.44        303    0.043970         0.912734
# 8          4.28 - 4.36        282    0.040923         0.953681
# 9           4.2 - 4.28        142    0.020607         0.974299
# 10          4.12 - 4.2        120    0.017414         0.991724
# 11         4.04 - 4.12         57    0.008272         1.000000

# %%
table29_1 = table29.drop(['percentage','cumulative_perc'], axis=1)
table29_1
# Out:
#    review_scores_value  frequency
# 0          4.68 - 4.76       1327
# 1           4.52 - 4.6       1248
# 2          4.76 - 4.84        810
# 3             4.92 - 5        773
# 4           4.6 - 4.68        717
# 5          4.84 - 4.92        622
# 6          4.44 - 4.52        486
# 7          4.36 - 4.44        303
# 8          4.28 - 4.36        282
# 9           4.2 - 4.28        142
# 10          4.12 - 4.2        120
# 11         4.04 - 4.12         57

# %%
Filtro29 = table29_1[table29_1['frequency']>1]
Filtro29
# Out:
#    review_scores_value  frequency
# 0          4.68 - 4.76       1327
# 1           4.52 - 4.6       1248
# 2          4.76 - 4.84        810
# 3             4.92 - 5        773
# 4           4.6 - 4.68        717
# 5          4.84 - 4.92        622
# 6          4.44 - 4.52        486
# 7          4.36 - 4.44        303
# 8          4.28 - 4.36        282
# 9           4.2 - 4.28        142
# 10          4.12 - 4.2        120
# 11         4.04 - 4.12         57

# %%
 
Filtro_index29 = Filtro29.set_index('review_scores_value')
Filtro_index29
# Out:
#                      frequency
# review_scores_value
# 4.68 - 4.76               1327
# 4.52 - 4.6                1248
# 4.76 - 4.84                810
# 4.92 - 5                   773
# 4.6 - 4.68                 717
# 4.84 - 4.92                622
# 4.44 - 4.52                486
# 4.36 - 4.44                303
# 4.28 - 4.36                282
# 4.2 - 4.28                 142
# 4.12 - 4.2                 120
# 4.04 - 4.12                 57

# %%
Filtro_index29.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Puntuacion del valor en las reseñas')
plt.xlabel('Puntuacion')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
 
table29.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Filtro_index29.plot(kind='area', figsize=(10,4), alpha = 0.8)
# Out:
# <Axes: xlabel='review_scores_value'>

# %%
Filtro_index29["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct= "%0.1f ")
# Out:
# <Axes: ylabel='frequency'>

# %%
 
doc['reviews_per_month'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6891 entries, 0 to 6890
# Series name: reviews_per_month
# Non-Null Count  Dtype
# --------------  -----
# 6891 non-null   float64
# dtypes: float64(1)
# memory usage: 54.0 KB

# %%
n
# Out:
# 6891

# %%
 
Max=doc['reviews_per_month'].max()
Min=doc['reviews_per_month'].min()
Limites =[Min, Max]
Limites
# Out:
# [0.01, 4.02]

# %%
 
R=Max- Min
R
# Out:
# 4.01

# %%
 
ni = 1+3.322*np.log10(n)
ni
# Out:
# 13.750773634216594

# %%
 
i = R/ni
i
# Out:
# 0.29161995584173955

# %%
 
intervalos=np.linspace(Min, Max, 13)
intervalos
# Out:
# array([0.01      , 0.34416667, 0.67833333, 1.0125    , 1.34666667,
#        1.68083333, 2.015     , 2.34916667, 2.68333333, 3.0175    ,
#        3.35166667, 3.68583333, 4.02      ])

# %%
categorias = ["0.01- 0.34", "0.34 - 0.67", "0.67 - 1.01", "1.01 - 1.34", "1.34 - 1.68", "1.68 - 2.01", "2.01 - 2.23", "2.34 - 2.68", "2.68- 3.01", "3.01 - 3.35", "3.35 - 3.68", "3.68 - 4.02"]

# %%
 
doc['reviews_per_month']=pd.cut(x= doc["reviews_per_month"], bins=intervalos, labels = categorias)
doc['reviews_per_month']
# Out:
# 0       1.01 - 1.34
# 1       0.34 - 0.67
# 2        0.01- 0.34
# 3        0.01- 0.34
# 4        0.01- 0.34
#            ...
# 6886    0.67 - 1.01
# 6887    0.67 - 1.01
# 6888    0.67 - 1.01
# 6889    0.67 - 1.01
# 6890    0.67 - 1.01
# Name: reviews_per_month, Length: 6891, dtype: category
# Categories (12, object): ['0.01- 0.34' < '0.34 - 0.67' < '0.67 - 1.01' < '1.01 - 1.34' ... '2.68- 3.01' < '3.01 - 3.35' < '3.35 - 3.68' < '3.68 - 4.02']

# %%
table30 = freq_tbl(doc['reviews_per_month'])
table30
# Out:
#    reviews_per_month  frequency  percentage  cumulative_perc
# 0        0.67 - 1.01       1545    0.224205         0.224629
# 1         0.01- 0.34       1354    0.196488         0.421489
# 2        1.01 - 1.34       1115    0.161805         0.583600
# 3        0.34 - 0.67       1024    0.148600         0.732480
# 4        1.34 - 1.68        432    0.062690         0.795289
# 5        1.68 - 2.01        349    0.050646         0.846031
# 6        2.01 - 2.23        269    0.039036         0.885141
# 7        2.34 - 2.68        214    0.031055         0.916255
# 8         2.68- 3.01        210    0.030475         0.946787
# 9        3.01 - 3.35        131    0.019010         0.965833
# 10       3.35 - 3.68        126    0.018285         0.984152
# 11       3.68 - 4.02        109    0.015818         1.000000

# %%
table30_1 = table30.drop(['percentage','cumulative_perc'], axis=1)
table30_1
# Out:
#    reviews_per_month  frequency
# 0        0.67 - 1.01       1545
# 1         0.01- 0.34       1354
# 2        1.01 - 1.34       1115
# 3        0.34 - 0.67       1024
# 4        1.34 - 1.68        432
# 5        1.68 - 2.01        349
# 6        2.01 - 2.23        269
# 7        2.34 - 2.68        214
# 8         2.68- 3.01        210
# 9        3.01 - 3.35        131
# 10       3.35 - 3.68        126
# 11       3.68 - 4.02        109

# %%
Filtro30 = table30_1[table30_1['frequency']>1]
Filtro30
# Out:
#    reviews_per_month  frequency
# 0        0.67 - 1.01       1545
# 1         0.01- 0.34       1354
# 2        1.01 - 1.34       1115
# 3        0.34 - 0.67       1024
# 4        1.34 - 1.68        432
# 5        1.68 - 2.01        349
# 6        2.01 - 2.23        269
# 7        2.34 - 2.68        214
# 8         2.68- 3.01        210
# 9        3.01 - 3.35        131
# 10       3.35 - 3.68        126
# 11       3.68 - 4.02        109

# %%
 
Filtro_index30 = Filtro30.set_index('reviews_per_month')
Filtro_index30
# Out:
#                    frequency
# reviews_per_month
# 0.67 - 1.01             1545
# 0.01- 0.34              1354
# 1.01 - 1.34             1115
# 0.34 - 0.67             1024
# 1.34 - 1.68              432
# 1.68 - 2.01              349
# 2.01 - 2.23              269
# 2.34 - 2.68              214
# 2.68- 3.01               210
# 3.01 - 3.35              131
# 3.35 - 3.68              126
# 3.68 - 4.02              109

# %%
Filtro_index30.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Reseñas mensuales')
plt.xlabel('Calificacion')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
 
table30.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Filtro_index30.plot(kind='area', figsize=(10,4), alpha = 0.8)
# Out:
# <Axes: xlabel='reviews_per_month'>

# %%
Filtro_index30["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct= "%0.1f ")
# Out:
# <Axes: ylabel='frequency'>

# %%
 
doc['review_scores_communication'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6891 entries, 0 to 6890
# Series name: review_scores_communication
# Non-Null Count  Dtype
# --------------  -----
# 6891 non-null   float64
# dtypes: float64(1)
# memory usage: 54.0 KB

# %%
n
# Out:
# 6891

# %%
 
Max=doc['review_scores_communication'].max()
Min=doc['review_scores_communication'].min()
Limites =[Min, Max]
Limites
# Out:
# [4.52, 5.0]

# %%
 
R=Max- Min
R
# Out:
# 0.4800000000000004

# %%
 
ni = 1+3.322*np.log10(n)
ni
# Out:
# 13.750773634216594

# %%
 
i = R/ni
i
# Out:
# 0.03490712688379928

# %%
 
intervalos=np.linspace(Min, Max, 13)
intervalos
# Out:
# array([4.52, 4.56, 4.6 , 4.64, 4.68, 4.72, 4.76, 4.8 , 4.84, 4.88, 4.92,
#        4.96, 5.  ])

# %%
categorias = ["4.52 - 4.56", "4.56 - 4.6", "4.6 - 4.64", "4.64 - 4.68", "4.68 - 4.72", "4.72 - 4.76", "4.76 - 4.8", "4.8 - 4.84", "4.84 - 4.88", "4.88 - 4.92", "4.92- 4.96", "4.96 - 5"]

# %%
 
doc['review_scores_communication']=pd.cut(x= doc["review_scores_communication"], bins=intervalos, labels = categorias)
doc['review_scores_communication']
# Out:
# 0          4.96 - 5
# 1        4.6 - 4.64
# 2       4.88 - 4.92
# 3       4.88 - 4.92
# 4       4.68 - 4.72
#            ...
# 6886     4.76 - 4.8
# 6887     4.76 - 4.8
# 6888     4.76 - 4.8
# 6889     4.76 - 4.8
# 6890     4.76 - 4.8
# Name: review_scores_communication, Length: 6891, dtype: category
# Categories (12, object): ['4.52 - 4.56' < '4.56 - 4.6' < '4.6 - 4.64' < '4.64 - 4.68' ... '4.84 - 4.88' < '4.88 - 4.92' < '4.92- 4.96' < '4.96 - 5']

# %%
table31 = freq_tbl(doc['review_scores_communication'])
table31
# Out:
#    review_scores_communication  frequency  percentage  cumulative_perc
# 0                     4.96 - 5       2222    0.322450         0.323012
# 1                  4.88 - 4.92       1126    0.163402         0.486699
# 2                   4.76 - 4.8        990    0.143666         0.630615
# 3                   4.92- 4.96        784    0.113772         0.744585
# 4                  4.84 - 4.88        506    0.073429         0.818142
# 5                   4.8 - 4.84        346    0.050210         0.868440
# 6                  4.72 - 4.76        243    0.035263         0.903765
# 7                  4.64 - 4.68        207    0.030039         0.933857
# 8                  4.68 - 4.72        163    0.023654         0.957552
# 9                   4.6 - 4.64        113    0.016398         0.973979
# 10                  4.56 - 4.6        102    0.014802         0.988807
# 11                 4.52 - 4.56         77    0.011174         1.000000

# %%
table31_1 = table31.drop(['percentage','cumulative_perc'], axis=1)
table31_1
# Out:
#    review_scores_communication  frequency
# 0                     4.96 - 5       2222
# 1                  4.88 - 4.92       1126
# 2                   4.76 - 4.8        990
# 3                   4.92- 4.96        784
# 4                  4.84 - 4.88        506
# 5                   4.8 - 4.84        346
# 6                  4.72 - 4.76        243
# 7                  4.64 - 4.68        207
# 8                  4.68 - 4.72        163
# 9                   4.6 - 4.64        113
# 10                  4.56 - 4.6        102
# 11                 4.52 - 4.56         77

# %%
Filtro31 = table31_1[table31_1['frequency']>1]
Filtro31
# Out:
#    review_scores_communication  frequency
# 0                     4.96 - 5       2222
# 1                  4.88 - 4.92       1126
# 2                   4.76 - 4.8        990
# 3                   4.92- 4.96        784
# 4                  4.84 - 4.88        506
# 5                   4.8 - 4.84        346
# 6                  4.72 - 4.76        243
# 7                  4.64 - 4.68        207
# 8                  4.68 - 4.72        163
# 9                   4.6 - 4.64        113
# 10                  4.56 - 4.6        102
# 11                 4.52 - 4.56         77

# %%
 
Filtro_index31 = Filtro31.set_index('review_scores_communication')
Filtro_index31
# Out:
#                              frequency
# review_scores_communication
# 4.96 - 5                          2222
# 4.88 - 4.92                       1126
# 4.76 - 4.8                         990
# 4.92- 4.96                         784
# 4.84 - 4.88                        506
# 4.8 - 4.84                         346
# 4.72 - 4.76                        243
# 4.64 - 4.68                        207
# 4.68 - 4.72                        163
# 4.6 - 4.64                         113
# 4.56 - 4.6                         102
# 4.52 - 4.56                         77

# %%
Filtro_index31.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Rseseñas del mes')
plt.xlabel('Calificacion')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
 
table31.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Filtro_index31.plot(kind='area', figsize=(10,4), alpha = 0.8)
# Out:
# <Axes: xlabel='review_scores_communication'>

# %%
Filtro_index31["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct= "%0.1f ")
# Out:
# <Axes: ylabel='frequency'>

# %%
 
doc['review_scores_checkin'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6891 entries, 0 to 6890
# Series name: review_scores_checkin
# Non-Null Count  Dtype
# --------------  -----
# 6891 non-null   float64
# dtypes: float64(1)
# memory usage: 54.0 KB

# %%
n
# Out:
# 6891

# %%
 
Max=doc['review_scores_checkin'].max()
Min=doc['review_scores_checkin'].min()
Limites =[Min, Max]
Limites
# Out:
# [4.45, 5.0]

# %%
 
R=Max- Min
R
# Out:
# 0.5499999999999998

# %%
 
ni = 1+3.322*np.log10(n)
ni
# Out:
# 13.750773634216594

# %%
 
i = R/ni
i
# Out:
# 0.03999774955435329

# %%
 
intervalos=np.linspace(Min, Max, 6)
intervalos
# Out:
# array([4.45, 4.56, 4.67, 4.78, 4.89, 5.  ])

# %%
categorias = ["4.45- 4.56", "4.56 - 4.67", "4.67 - 4.78", "4.78 - 4.89", "4.49 - 5"]

# %%
 
doc['review_scores_checkin']=pd.cut(x= doc["review_scores_checkin"], bins=intervalos, labels = categorias)
doc['review_scores_checkin']
# Out:
# 0          4.49 - 5
# 1        4.45- 4.56
# 2       4.56 - 4.67
# 3       4.78 - 4.89
# 4       4.67 - 4.78
#            ...
# 6886    4.78 - 4.89
# 6887    4.78 - 4.89
# 6888    4.78 - 4.89
# 6889    4.78 - 4.89
# 6890    4.78 - 4.89
# Name: review_scores_checkin, Length: 6891, dtype: category
# Categories (5, object): ['4.45- 4.56' < '4.56 - 4.67' < '4.67 - 4.78' < '4.78 - 4.89' < '4.49 - 5']

# %%
table32 = freq_tbl(doc['review_scores_checkin'])
table32
# Out:
#   review_scores_checkin  frequency  percentage  cumulative_perc
# 0              4.49 - 5       2740    0.397620         0.397967
# 1           4.78 - 4.89       2597    0.376868         0.775163
# 2           4.67 - 4.78        746    0.108257         0.883515
# 3           4.56 - 4.67        506    0.073429         0.957008
# 4            4.45- 4.56        296    0.042955         1.000000

# %%
table32_1 = table32.drop(['percentage','cumulative_perc'], axis=1)
table32_1
# Out:
#   review_scores_checkin  frequency
# 0              4.49 - 5       2740
# 1           4.78 - 4.89       2597
# 2           4.67 - 4.78        746
# 3           4.56 - 4.67        506
# 4            4.45- 4.56        296

# %%
Filtro32 = table32_1[table32_1['frequency']>1]
Filtro32
# Out:
#   review_scores_checkin  frequency
# 0              4.49 - 5       2740
# 1           4.78 - 4.89       2597
# 2           4.67 - 4.78        746
# 3           4.56 - 4.67        506
# 4            4.45- 4.56        296

# %%
 
Filtro_index32 = Filtro32.set_index('review_scores_checkin')
Filtro_index32
# Out:
#                        frequency
# review_scores_checkin
# 4.49 - 5                    2740
# 4.78 - 4.89                 2597
# 4.67 - 4.78                  746
# 4.56 - 4.67                  506
# 4.45- 4.56                   296

# %%
Filtro_index32.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Puntuacion del registro de entrada')
plt.xlabel('Puntuacion')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
 
table32.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Filtro_index32.plot(kind='area', figsize=(10,4), alpha = 0.8)
# Out:
# <Axes: xlabel='review_scores_checkin'>

# %%
Filtro_index32["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct= "%0.1f ")
# Out:
# <Axes: ylabel='frequency'>

# %%
 
doc['review_scores_cleanliness'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6891 entries, 0 to 6890
# Series name: review_scores_cleanliness
# Non-Null Count  Dtype
# --------------  -----
# 6891 non-null   float64
# dtypes: float64(1)
# memory usage: 54.0 KB

# %%
n
# Out:
# 6891

# %%
 
Max=doc['review_scores_cleanliness'].max()
Min=doc['review_scores_cleanliness'].min()
Limites =[Min, Max]
Limites
# Out:
# [4.32, 5.0]

# %%
 
R=Max- Min
R
# Out:
# 0.6799999999999997

# %%
 
ni = 1+3.322*np.log10(n)
ni
# Out:
# 13.750773634216594

# %%
 
i = R/ni
i
# Out:
# 0.04945176308538225

# %%
 
intervalos=np.linspace(Min, Max, 13)
intervalos
# Out:
# array([4.32      , 4.37666667, 4.43333333, 4.49      , 4.54666667,
#        4.60333333, 4.66      , 4.71666667, 4.77333333, 4.83      ,
#        4.88666667, 4.94333333, 5.        ])

# %%
#Creamos las categorias
categorias= ["4.32 - 4.37", "4.37 - 4.43", "4.43 - 4.49", "4.49 - 4.54", "4.54 - 4.60", "4.60 - 4.66", "4.66 - 4.71", "4.71 - 4.77", "4.77 - 4.83", "4.83 - 4.88", "4.88 - 4.94", "4.94 - 5"]

# %%
 
doc['review_scores_cleanliness']=pd.cut(x= doc["review_scores_cleanliness"], bins=intervalos, labels = categorias)
doc['review_scores_cleanliness']
# Out:
# 0       4.71 - 4.77
# 1       4.88 - 4.94
# 2       4.77 - 4.83
# 3       4.77 - 4.83
# 4       4.77 - 4.83
#            ...
# 6886    4.77 - 4.83
# 6887    4.77 - 4.83
# 6888    4.77 - 4.83
# 6889    4.77 - 4.83
# 6890    4.77 - 4.83
# Name: review_scores_cleanliness, Length: 6891, dtype: category
# Categories (12, object): ['4.32 - 4.37' < '4.37 - 4.43' < '4.43 - 4.49' < '4.49 - 4.54' ... '4.77 - 4.83' < '4.83 - 4.88' < '4.88 - 4.94' < '4.94 - 5']

# %%
table33 = freq_tbl(doc['review_scores_cleanliness'])
table33
# Out:
#    review_scores_cleanliness  frequency  percentage  cumulative_perc
# 0                   4.94 - 5       1883    0.273255         0.273493
# 1                4.77 - 4.83       1763    0.255841         0.529557
# 2                4.88 - 4.94        873    0.126687         0.656354
# 3                4.83 - 4.88        566    0.082136         0.738562
# 4                4.71 - 4.77        429    0.062255         0.800871
# 5                4.66 - 4.71        382    0.055435         0.856354
# 6                4.60 - 4.66        247    0.035844         0.892229
# 7                4.54 - 4.60        223    0.032361         0.924619
# 8                4.49 - 4.54        219    0.031781         0.956427
# 9                4.43 - 4.49        104    0.015092         0.971532
# 10               4.37 - 4.43        102    0.014802         0.986347
# 11               4.32 - 4.37         94    0.013641         1.000000

# %%
table33_1 = table33.drop(['percentage','cumulative_perc'], axis=1)
table33_1
# Out:
#    review_scores_cleanliness  frequency
# 0                   4.94 - 5       1883
# 1                4.77 - 4.83       1763
# 2                4.88 - 4.94        873
# 3                4.83 - 4.88        566
# 4                4.71 - 4.77        429
# 5                4.66 - 4.71        382
# 6                4.60 - 4.66        247
# 7                4.54 - 4.60        223
# 8                4.49 - 4.54        219
# 9                4.43 - 4.49        104
# 10               4.37 - 4.43        102
# 11               4.32 - 4.37         94

# %%
Filtro33 = table33_1[table33_1['frequency']>1]
Filtro33
# Out:
#    review_scores_cleanliness  frequency
# 0                   4.94 - 5       1883
# 1                4.77 - 4.83       1763
# 2                4.88 - 4.94        873
# 3                4.83 - 4.88        566
# 4                4.71 - 4.77        429
# 5                4.66 - 4.71        382
# 6                4.60 - 4.66        247
# 7                4.54 - 4.60        223
# 8                4.49 - 4.54        219
# 9                4.43 - 4.49        104
# 10               4.37 - 4.43        102
# 11               4.32 - 4.37         94

# %%
 
Filtro_index33 = Filtro33.set_index('review_scores_cleanliness')
Filtro_index33
# Out:
#                            frequency
# review_scores_cleanliness
# 4.94 - 5                        1883
# 4.77 - 4.83                     1763
# 4.88 - 4.94                      873
# 4.83 - 4.88                      566
# 4.71 - 4.77                      429
# 4.66 - 4.71                      382
# 4.60 - 4.66                      247
# 4.54 - 4.60                      223
# 4.49 - 4.54                      219
# 4.43 - 4.49                      104
# 4.37 - 4.43                      102
# 4.32 - 4.37                       94

# %%
Filtro_index33.plot(kind = 'bar', width=0.8, figsize=(10,4), color = "red")
plt.title('Clificacion de la limpieza')
plt.xlabel('Calificacion')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
 
table33.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
Filtro_index33.plot(kind='area', figsize=(10,4), alpha = 0.8)
# Out:
# <Axes: xlabel='review_scores_cleanliness'>

# %%
Filtro_index33["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct= "%0.1f ")
# Out:
# <Axes: ylabel='frequency'>
