# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mtp
import seaborn as se

# %%
doc= pd.read_csv('listings.csv')
doc
# Out:
#                        id                                       listing_url  \
# 0                     360                  https://www.airbnb.com/rooms/360
# 1                     364                  https://www.airbnb.com/rooms/364
# 2                     590                  https://www.airbnb.com/rooms/590
# 3                     592                  https://www.airbnb.com/rooms/592
# 4                    1940                 https://www.airbnb.com/rooms/1940
# ...                   ...                                               ...
# 5154  1251065910742730822  https://www.airbnb.com/rooms/1251065910742730822
# 5155  1252260719153566618  https://www.airbnb.com/rooms/1252260719153566618
# 5156  1252928973496743308  https://www.airbnb.com/rooms/1252928973496743308
# 5157  1253197149740270387  https://www.airbnb.com/rooms/1253197149740270387
# 5158  1253756160013939941  https://www.airbnb.com/rooms/1253756160013939941
#
#            scrape_id last_scraped           source  \
# ...

# %%
fil1=doc[doc["host_name"].isin(["Susan", "Jason", "Kerry", "Valerie", "Jonh"])]
fil1
# Out:
#                        id                                       listing_url  \
# 1                     364                  https://www.airbnb.com/rooms/364
# 9                  154999               https://www.airbnb.com/rooms/154999
# 16                 575758               https://www.airbnb.com/rooms/575758
# 17                 632709               https://www.airbnb.com/rooms/632709
# 50                1733052              https://www.airbnb.com/rooms/1733052
# ...                   ...                                               ...
# 4831  1171691253476264465  https://www.airbnb.com/rooms/1171691253476264465
# 4895  1183304830651878419  https://www.airbnb.com/rooms/1183304830651878419
# 5122  1242233383389748068  https://www.airbnb.com/rooms/1242233383389748068
# 5156  1252928973496743308  https://www.airbnb.com/rooms/1252928973496743308
# 5158  1253756160013939941  https://www.airbnb.com/rooms/1253756160013939941
#
#            scrape_id last_scraped           source  \
# ...

# %%
fil2= doc[doc['host_since']< "2019-01-01"]
fil2
# Out:
#                        id                                       listing_url  \
# 0                     360                  https://www.airbnb.com/rooms/360
# 1                     364                  https://www.airbnb.com/rooms/364
# 2                     590                  https://www.airbnb.com/rooms/590
# 3                     592                  https://www.airbnb.com/rooms/592
# 4                    1940                 https://www.airbnb.com/rooms/1940
# ...                   ...                                               ...
# 5151  1250600873046204552  https://www.airbnb.com/rooms/1250600873046204552
# 5153  1251000119322848545  https://www.airbnb.com/rooms/1251000119322848545
# 5154  1251065910742730822  https://www.airbnb.com/rooms/1251065910742730822
# 5155  1252260719153566618  https://www.airbnb.com/rooms/1252260719153566618
# 5157  1253197149740270387  https://www.airbnb.com/rooms/1253197149740270387
#
#            scrape_id last_scraped           source  \
# ...

# %%
fil3=doc[doc['host_response_time']== "within a day"]
fil3
# Out:
#                        id                                       listing_url  \
# 12                 364585               https://www.airbnb.com/rooms/364585
# 13                 370209               https://www.airbnb.com/rooms/370209
# 24                 776434               https://www.airbnb.com/rooms/776434
# 29                1041934              https://www.airbnb.com/rooms/1041934
# 30                1042331              https://www.airbnb.com/rooms/1042331
# ...                   ...                                               ...
# 5065  1225397178953388868  https://www.airbnb.com/rooms/1225397178953388868
# 5076  1229105058776272560  https://www.airbnb.com/rooms/1229105058776272560
# 5115  1240778179259241692  https://www.airbnb.com/rooms/1240778179259241692
# 5118  1241763968451704417  https://www.airbnb.com/rooms/1241763968451704417
# 5123  1242377483535775578  https://www.airbnb.com/rooms/1242377483535775578
#
#            scrape_id last_scraped       source  \
# ...

# %%
fil4=doc[doc['accommodates'] >= 5]
fil4
# Out:
#                        id                                       listing_url  \
# 12                 364585               https://www.airbnb.com/rooms/364585
# 18                 676825               https://www.airbnb.com/rooms/676825
# 20                 732845               https://www.airbnb.com/rooms/732845
# 24                 776434               https://www.airbnb.com/rooms/776434
# 39                1313699              https://www.airbnb.com/rooms/1313699
# ...                   ...                                               ...
# 5140  1247359326976934287  https://www.airbnb.com/rooms/1247359326976934287
# 5142  1248031702909090051  https://www.airbnb.com/rooms/1248031702909090051
# 5143  1248597640020149763  https://www.airbnb.com/rooms/1248597640020149763
# 5144  1249458778389680152  https://www.airbnb.com/rooms/1249458778389680152
# 5145  1249482151822012501  https://www.airbnb.com/rooms/1249482151822012501
#
#            scrape_id last_scraped           source  \
# ...

# %%
fil5=doc[(doc['room_type']== "Entire home/apt") | (doc['room_type']== "Private room")]
fil5
# Out:
#                        id                                       listing_url  \
# 0                     360                  https://www.airbnb.com/rooms/360
# 1                     364                  https://www.airbnb.com/rooms/364
# 2                     590                  https://www.airbnb.com/rooms/590
# 3                     592                  https://www.airbnb.com/rooms/592
# 4                    1940                 https://www.airbnb.com/rooms/1940
# ...                   ...                                               ...
# 5154  1251065910742730822  https://www.airbnb.com/rooms/1251065910742730822
# 5155  1252260719153566618  https://www.airbnb.com/rooms/1252260719153566618
# 5156  1252928973496743308  https://www.airbnb.com/rooms/1252928973496743308
# 5157  1253197149740270387  https://www.airbnb.com/rooms/1253197149740270387
# 5158  1253756160013939941  https://www.airbnb.com/rooms/1253756160013939941
#
#            scrape_id last_scraped           source  \
# ...

# %%
fil6= doc[doc['beds']<=4]
fil6
# Out:
#                        id                                       listing_url  \
# 0                     360                  https://www.airbnb.com/rooms/360
# 2                     590                  https://www.airbnb.com/rooms/590
# 3                     592                  https://www.airbnb.com/rooms/592
# 4                    1940                 https://www.airbnb.com/rooms/1940
# 5                   21745                https://www.airbnb.com/rooms/21745
# ...                   ...                                               ...
# 5154  1251065910742730822  https://www.airbnb.com/rooms/1251065910742730822
# 5155  1252260719153566618  https://www.airbnb.com/rooms/1252260719153566618
# 5156  1252928973496743308  https://www.airbnb.com/rooms/1252928973496743308
# 5157  1253197149740270387  https://www.airbnb.com/rooms/1253197149740270387
# 5158  1253756160013939941  https://www.airbnb.com/rooms/1253756160013939941
#
#            scrape_id last_scraped       source  \
# ...

# %%
fil7=doc[((doc['bathrooms']==1)|(doc['host_is_superhost']=='t'))&(doc['instant_bookable']=="t")]
fil7
# Out:
#                        id                                       listing_url  \
# 79                3150813              https://www.airbnb.com/rooms/3150813
# 86                3479122              https://www.airbnb.com/rooms/3479122
# 100               4224189              https://www.airbnb.com/rooms/4224189
# 120               4753876              https://www.airbnb.com/rooms/4753876
# 129               5364164              https://www.airbnb.com/rooms/5364164
# ...                   ...                                               ...
# 5110  1238597499121708021  https://www.airbnb.com/rooms/1238597499121708021
# 5113  1239246932631802469  https://www.airbnb.com/rooms/1239246932631802469
# 5116  1240792080633926879  https://www.airbnb.com/rooms/1240792080633926879
# 5121  1242194110216996261  https://www.airbnb.com/rooms/1242194110216996261
# 5132  1245616343744998886  https://www.airbnb.com/rooms/1245616343744998886
#
#            scrape_id last_scraped       source  \
# ...

# %%
fil8=doc[(doc['review_scores_cleanliness']<3)&(doc['review_scores_rating']>3)]
fil8
# Out:
#                       id                                      listing_url  \
# 2066            52702783            https://www.airbnb.com/rooms/52702783
# 2713  667628284519365493  https://www.airbnb.com/rooms/667628284519365493
#
#            scrape_id last_scraped           source  \
# 2066  20240928232601   2024-09-29      city scrape
# 2713  20240928232601   2024-09-29  previous scrape
#
#                                                  name  \
# 2066  Private room in shared house, great location :)
# 2713                     Tiny room near D-town Denver
#
#                                             description neighborhood_overview  \
# 2066  Please message us before booking instantly - w...                   NaN
# 2713  This place is located in Denver within half a ...                   NaN
#
#                                             picture_url    host_id  ...  \
# 2066  https://a0.muscache.com/pictures/bf0783dc-bd64...   24483378  ...
# ...

# %%
fil1.to_csv("filtro1.csv")

# %%
fil2.to_csv("filtro2.csv")
fil3.to_csv("filtro3.csv")
fil4.to_csv("filtro4.csv")
fil5.to_csv("filtro5.csv")
fil6.to_csv("filtro6.csv")
fil7.to_csv("filtro7.csv")
fil8.to_csv("filtro8.csv")
